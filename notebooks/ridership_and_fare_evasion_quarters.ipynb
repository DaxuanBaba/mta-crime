# %%
# !pip install pygwalker
# Out:
# ...
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      -------------------------------------- 107.3/107.3 kB 6.5 MB/s eta 0:00:00
# ...
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------------- ------------------ 1.2/2.2 MB 38.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 34.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------- ----------------------------- 2.4/9.7 MB 53.0 MB/s eta 0:00:01
#    --------------- ------------------------ 3.8/9.7 MB 40.5 MB/s eta 0:00:01
#    ------------------------- -------------- 6.2/9.7 MB 49.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.7 MB 51.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 47.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import pygwalker as pyg
